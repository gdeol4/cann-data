# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# test case: EGFR
target = new_client.target
target_query = target.search('TRPV1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references                organism  \
# 0  [{'xref_id': 'TRPV1', 'xref_name': None, 'xref...            Homo sapiens
# 1  [{'xref_id': 'Q6R5A3', 'xref_name': None, 'xre...         Cavia porcellus
# 2  [{'xref_id': 'Q697L1', 'xref_name': None, 'xre...  Canis lupus familiaris
# 3                                                 []            Mus musculus
# 4  [{'xref_id': 'O35433', 'xref_name': None, 'xre...       Rattus norvegicus
# 5                                                 []           Gallus gallus
# 6                                                 []       Rattus norvegicus
#
#                                            pref_name  score  \
# 0                                 Vanilloid receptor   16.0
# 1                               Vanilloid receptor 1   16.0
# 2                               Vanilloid receptor 1   16.0
# 3  Transient receptor potential cation channel su...   16.0
# 4                                 Vanilloid receptor   15.0
# 5                            Uncharacterized protein   13.0
# 6                                 Vanilloid receptor    9.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL4794
# 1               False       CHEMBL5132
# 2               False       CHEMBL5254
# 3               False    CHEMBL1781864
# 4               False       CHEMBL5102
# 5               False    CHEMBL2412949
# 6               False    CHEMBL2096684
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'Q8NER1', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'Q6R5A3', 'component_descriptio...  SINGLE PROTEIN   10141
# 2  [{'accession': 'Q697L1', 'component_descriptio...  SINGLE PROTEIN    9615
# 3  [{'accession': 'Q704Y3', 'component_descriptio...  SINGLE PROTEIN   10090
# 4  [{'accession': 'O35433', 'component_descriptio...  SINGLE PROTEIN   10116
# 5  [{'accession': 'F1NJH8', 'component_descriptio...  SINGLE PROTEIN    9031
# 6  [{'accession': 'Q9ERZ8', 'component_descriptio...  PROTEIN FAMILY   10116

# %%
# select the target of interest from the search results
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4794'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None       632519                  []    CHEMBL820091
# 1                None       632521                  []    CHEMBL820091
# 2                None       633813                  []    CHEMBL820091
# 3                None       637294                  []    CHEMBL820091
# 4                None       639749                  []    CHEMBL820091
# ...               ...          ...                 ...             ...
# 3812             None     22994535                  []   CHEMBL4775810
# 3813             None     22994536                  []   CHEMBL4775810
# 3814             None     22994538                  []   CHEMBL4775810
# 3815       Not Active     23117599                  []   CHEMBL4513051
# 3816       Not Active     23117608                  []   CHEMBL4513051
#
#                                       assay_description assay_type  \
# 0     Antagonistic activity towards human vanilloid ...          F
# 1     Antagonistic activity towards human vanilloid ...          F
# 2     Antagonistic activity towards human vanilloid ...          F
# 3     Antagonistic activity towards human vanilloid ...          F
# 4     Antagonistic activity towards human vanilloid ...          F
# ...                                                 ...        ...
# 3812  Antagonist activity at human TRPV1 expressed i...          B
# 3813  Antagonist activity at human TRPV1 expressed i...          B
# 3814  Antagonist activity at human TRPV1 expressed i...          B
# 3815                     TRP selectivity screen (TRPV1)          B
# 3816                     TRP selectivity screen (TRPV1)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3812                    None                   None  BAO_0000179  BAO_0000219
# 3813                    None                   None  BAO_0000179  BAO_0000219
# 3814                    None                   None  BAO_0000179  BAO_0000219
# 3815                    None                   None  BAO_0000179  BAO_0000357
# 3816                    None                   None  BAO_0000179  BAO_0000357
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 1     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 2     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 4     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 3812  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3813  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3814  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3815  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3816  ...    Homo sapiens  Vanilloid receptor          9606       None  None
#
#       type  units    uo_units upper_value value
# 0     IC50     nM  UO_0000065        None   6.0
# 1     IC50     nM  UO_0000065        None  13.0
# 2     IC50     nM  UO_0000065        None  10.0
# 3     IC50     nM  UO_0000065        None   6.0
# 4     IC50     nM  UO_0000065        None  32.0
# ...    ...    ...         ...         ...   ...
# 3812  IC50     nM        None        None  4.41
# 3813  IC50     nM        None        None  6.17
# 3814  IC50     nM        None        None  0.27
# 3815  IC50     µM        None        None  25.0
# 3816  IC50     µM        None        None  25.0
#
# [3817 rows x 45 columns]

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipykernel_52707/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None       632519                  []    CHEMBL820091
# 1                None       632521                  []    CHEMBL820091
# 2                None       633813                  []    CHEMBL820091
# 3                None       637294                  []    CHEMBL820091
# 4                None       639749                  []    CHEMBL820091
# ...               ...          ...                 ...             ...
# 3812             None     22994535                  []   CHEMBL4775810
# 3813             None     22994536                  []   CHEMBL4775810
# 3814             None     22994538                  []   CHEMBL4775810
# 3815       Not Active     23117599                  []   CHEMBL4513051
# 3816       Not Active     23117608                  []   CHEMBL4513051
#
#                                       assay_description assay_type  \
# 0     Antagonistic activity towards human vanilloid ...          F
# 1     Antagonistic activity towards human vanilloid ...          F
# 2     Antagonistic activity towards human vanilloid ...          F
# 3     Antagonistic activity towards human vanilloid ...          F
# 4     Antagonistic activity towards human vanilloid ...          F
# ...                                                 ...        ...
# 3812  Antagonist activity at human TRPV1 expressed i...          B
# 3813  Antagonist activity at human TRPV1 expressed i...          B
# 3814  Antagonist activity at human TRPV1 expressed i...          B
# 3815                     TRP selectivity screen (TRPV1)          B
# 3816                     TRP selectivity screen (TRPV1)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3812                    None                   None  BAO_0000179  BAO_0000219
# 3813                    None                   None  BAO_0000179  BAO_0000219
# 3814                    None                   None  BAO_0000179  BAO_0000219
# 3815                    None                   None  BAO_0000179  BAO_0000357
# 3816                    None                   None  BAO_0000179  BAO_0000357
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 1     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 2     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 4     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 3812  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3813  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3814  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3815  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3816  ...    Homo sapiens  Vanilloid receptor          9606       None  None
#
#       type  units    uo_units upper_value value
# 0     IC50     nM  UO_0000065        None   6.0
# 1     IC50     nM  UO_0000065        None  13.0
# 2     IC50     nM  UO_0000065        None  10.0
# 3     IC50     nM  UO_0000065        None   6.0
# 4     IC50     nM  UO_0000065        None  32.0
# ...    ...    ...         ...         ...   ...
# 3812  IC50     nM        None        None  4.41
# 3813  IC50     nM        None        None  6.17
# 3814  IC50     nM        None        None  0.27
# 3815  IC50     µM        None        None  25.0
# 3816  IC50     µM        None        None  25.0
#
# [3695 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3109

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None       632519                  []    CHEMBL820091
# 1                None       632521                  []    CHEMBL820091
# 2                None       633813                  []    CHEMBL820091
# 3                None       637294                  []    CHEMBL820091
# 4                None       639749                  []    CHEMBL820091
# ...               ...          ...                 ...             ...
# 3812             None     22994535                  []   CHEMBL4775810
# 3813             None     22994536                  []   CHEMBL4775810
# 3814             None     22994538                  []   CHEMBL4775810
# 3815       Not Active     23117599                  []   CHEMBL4513051
# 3816       Not Active     23117608                  []   CHEMBL4513051
#
#                                       assay_description assay_type  \
# 0     Antagonistic activity towards human vanilloid ...          F
# 1     Antagonistic activity towards human vanilloid ...          F
# 2     Antagonistic activity towards human vanilloid ...          F
# 3     Antagonistic activity towards human vanilloid ...          F
# 4     Antagonistic activity towards human vanilloid ...          F
# ...                                                 ...        ...
# 3812  Antagonist activity at human TRPV1 expressed i...          B
# 3813  Antagonist activity at human TRPV1 expressed i...          B
# 3814  Antagonist activity at human TRPV1 expressed i...          B
# 3815                     TRP selectivity screen (TRPV1)          B
# 3816                     TRP selectivity screen (TRPV1)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000219
# 1                       None                   None  BAO_0000190  BAO_0000219
# 2                       None                   None  BAO_0000190  BAO_0000219
# 3                       None                   None  BAO_0000190  BAO_0000219
# 4                       None                   None  BAO_0000190  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3812                    None                   None  BAO_0000179  BAO_0000219
# 3813                    None                   None  BAO_0000179  BAO_0000219
# 3814                    None                   None  BAO_0000179  BAO_0000219
# 3815                    None                   None  BAO_0000179  BAO_0000357
# 3816                    None                   None  BAO_0000179  BAO_0000357
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 1     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 2     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 4     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 3812  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3813  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3814  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3815  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3816  ...    Homo sapiens  Vanilloid receptor          9606       None  None
#
#       type  units    uo_units upper_value value
# 0     IC50     nM  UO_0000065        None   6.0
# 1     IC50     nM  UO_0000065        None  13.0
# 2     IC50     nM  UO_0000065        None  10.0
# 3     IC50     nM  UO_0000065        None   6.0
# 4     IC50     nM  UO_0000065        None  32.0
# ...    ...    ...         ...         ...   ...
# 3812  IC50     nM        None        None  4.41
# 3813  IC50     nM        None        None  6.17
# 3814  IC50     nM        None        None  0.27
# 3815  IC50     µM        None        None  25.0
# 3816  IC50     µM        None        None  25.0
#
# [3109 rows x 45 columns]

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3812      CHEMBL4780532  CC(C)(C)c1cc(CNC(=O)Nc2cccc3[nH]c(=O)ccc23)n(-...
# 3813      CHEMBL4782987  CC(C)(C)c1cc(CNC(=O)Nc2cccc3[nH]c(=O)ccc23)n(-...
# 3814      CHEMBL4781687  CC1CCN(c2nc(C(F)(F)F)ccc2CNC(=O)Nc2cccc3[nH]c(...
# 3815      CHEMBL4514203             O[C@]1(C(F)(F)F)CCCC[C@H]1Nc1ccc(F)cc1
# 3816      CHEMBL4555711          COc1cc(N[C@@H]2CCCC[C@]2(O)C(F)(F)F)ccc1F
#
#      standard_value
# 0               6.0
# 1              13.0
# 2              10.0
# 3               6.0
# 4              32.0
# ...             ...
# 3812           4.41
# 3813           6.17
# 3814           0.27
# 3815           25.0
# 3816           25.0
#
# [3695 rows x 3 columns]

# %%
df4 = df3.copy()

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3812      CHEMBL4780532  CC(C)(C)c1cc(CNC(=O)Nc2cccc3[nH]c(=O)ccc23)n(-...
# 3813      CHEMBL4782987  CC(C)(C)c1cc(CNC(=O)Nc2cccc3[nH]c(=O)ccc23)n(-...
# 3814      CHEMBL4781687  CC1CCN(c2nc(C(F)(F)F)ccc2CNC(=O)Nc2cccc3[nH]c(...
# 3815      CHEMBL4514203             O[C@]1(C(F)(F)F)CCCC[C@H]1Nc1ccc(F)cc1
# 3816      CHEMBL4555711          COc1cc(N[C@@H]2CCCC[C@]2(O)C(F)(F)F)ccc1F
#
#      standard_value
# 0               6.0
# 1              13.0
# 2              10.0
# 3               6.0
# 4              32.0
# ...             ...
# 3812           4.41
# 3813           6.17
# 3814           0.27
# 3815           25.0
# 3816           25.0
#
# [3695 rows x 3 columns]

# %% [markdown]
# Labeling compounds as active, inactive, or intermediate
# The IC50 unit contains the bioactivity data. Compounds are classified accourding to the following parameters:
#
# Active: IC50 <= 1,000 nM
# Inactive: IC50 >= 10,000 nM
# Values in between 1,000 and 10,000 nM will be considered as intermediate.

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
# adds bioactivity class to the dataframe
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3666                NaN                                                NaN
# 3667                NaN                                                NaN
# 3668                NaN                                                NaN
# 3674                NaN                                                NaN
# 3680                NaN                                                NaN
#
#      standard_value     class
# 0               6.0    active
# 1              13.0    active
# 2              10.0    active
# 3               6.0    active
# 4              32.0    active
# ...             ...       ...
# 3666            NaN    active
# 3667            NaN  inactive
# 3668            NaN    active
# 3674            NaN    active
# 3680            NaN    active
#
# [3784 rows x 4 columns]

# %%
df6 = df5.loc[df5['class'] == 'active']

# %%
df6
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3614                NaN                                                NaN
# 3666                NaN                                                NaN
# 3668                NaN                                                NaN
# 3674                NaN                                                NaN
# 3680                NaN                                                NaN
#
#      standard_value   class
# 0               6.0  active
# 1              13.0  active
# 2              10.0  active
# 3               6.0  active
# 4              32.0  active
# ...             ...     ...
# 3614            NaN  active
# 3666            NaN  active
# 3668            NaN  active
# 3674            NaN  active
# 3680            NaN  active
#
# [2637 rows x 4 columns]
